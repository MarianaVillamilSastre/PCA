# %%
import numpy as np
from scipy import fftpack
from scipy.signal import convolve2d
import matplotlib.pyplot as plt

# %%
imagen1= plt.imread("20_popc_cho009-1.tif")
print(np.shape(img))
figura= figure(1, figsize=(10.5,8.5))
imshow(imagen1[:,:], cmap = cm.Greys_r)
plt.title('Imagen Original', fontsize=12)
# Out:
# (560, 512)

# %%
x= np.linspace(-10, 10, 20)
gaussiana =np.exp(-0.005*x**2)
gaussiana = gaussiana / np.trapz(gaussiana)
kernel =gaussiana[:, np.newaxis] * gaussiana[np.newaxis, :]
print(imagen1.shape[:2])

kernel1= fftpack.fft2(kernel, shape=imagen1.shape[:2], axes=(0, 1))

imgft_1 = fftpack.fft2(imagen1, axes=(0, 1))

imgft_2 = kernel1[:,:] * imgft_1

img2 = fftpack.ifft2(imgft_2, axes=(0, 1)).real

figura = figure(1, figsize=(9.5,9))
imshow(img2, cmap = cm.Greys_r)
# Out:
# (560, 512)

# %%
x= np.linspace(-10, 10, 20)
gaussiana =1-np.exp(-0.005*x**2)
gaussiana = gaussiana / np.trapz(gaussiana)
kernel =gaussiana[:, np.newaxis] * gaussiana[np.newaxis, :]
print(imagen1.shape[:2])

kernel1= fftpack.fft2(kernel, shape=imagen1.shape[:2], axes=(0, 1))

imgft_1 = fftpack.fft2(imagen1, axes=(0, 1))

imgft_2 = kernel1[:,:] * imgft_1

img2 = fftpack.ifft2(imgft_2, axes=(0, 1)).real

figura = figure(1, figsize=(9.5,9))
imshow(img2, cmap = cm.Greys_r)
# Out:
# (560, 512)

# %%
imagen2= plt.imread("colesterol-1.tif")
print(np.shape(imagen2))
figura= figure(1, figsize=(10.5,8.5))
imshow(imagen2[:,:], cmap = cm.Greys_r)
plt.title('Imagen Original', fontsize=12)
# Out:
# (244, 357)

# %%
x= np.linspace(-10, 10, 20)
gaussiana =1-np.exp(-0.005*x**2)
gaussiana = gaussiana / np.trapz(gaussiana)
kernel =gaussiana[:, np.newaxis] * gaussiana[np.newaxis, :]
print(imagen2.shape[:2])

kernel1= fftpack.fft2(kernel, shape=imagen2.shape[:2], axes=(0, 1))

imgft_1 = fftpack.fft2(imagen2, axes=(0, 1))

imgft_2 = kernel1[:,:] * imgft_1

img2 = fftpack.ifft2(imgft_2, axes=(0, 1)).real

figura = figure(1, figsize=(9.5,9))
imshow(img2, cmap = cm.Greys_r)
# Out:
# (244, 357)

# %%
x= np.linspace(-10, 10, 20)
gaussiana =np.exp(-0.005*x**2)
gaussiana = gaussiana / np.trapz(gaussiana)
kernel =gaussiana[:, np.newaxis] * gaussiana[np.newaxis, :]
print(imagen2.shape[:2])

kernel1= fftpack.fft2(kernel, shape=imagen2.shape[:2], axes=(0, 1))

imgft_1 = fftpack.fft2(imagen2, axes=(0, 1))

imgft_2 = kernel1[:,:] * imgft_1

img2 = fftpack.ifft2(imgft_2, axes=(0, 1)).real

figura = figure(1, figsize=(9.5,9))
imshow(img2, cmap = cm.Greys_r)
# Out:
# (244, 357)

# %%
imagen3= plt.imread("ves_full_150_002-1.tif")
print(np.shape(imagen3))
figura= figure(1, figsize=(10.5,8.5))
imshow(imagen3[:,:], cmap = cm.Greys_r)
plt.title('Imagen Original', fontsize=12)
# Out:
# (576, 544)

# %%
x= np.linspace(-10, 10, 20)
gaussiana =np.exp(-0.005*x**2)
gaussiana = gaussiana / np.trapz(gaussiana)
kernel =gaussiana[:, np.newaxis] * gaussiana[np.newaxis, :]
print(imagen3.shape[:2])

kernel1= fftpack.fft2(kernel, shape=imagen3.shape[:2], axes=(0, 1))

imgft_1 = fftpack.fft2(imagen3, axes=(0, 1))

imgft_2 = kernel1[:,:] * imgft_1

img2 = fftpack.ifft2(imgft_2, axes=(0, 1)).real

figura = figure(1, figsize=(9.5,9))
imshow(img2, cmap = cm.Greys_r)
# Out:
# (576, 544)

# %%
x= np.linspace(-10, 10, 20)
gaussiana =1-np.exp(-0.005*x**2)
gaussiana = gaussiana / np.trapz(gaussiana)
kernel =gaussiana[:, np.newaxis] * gaussiana[np.newaxis, :]
print(imagen3.shape[:2])

kernel1= fftpack.fft2(kernel, shape=imagen3.shape[:2], axes=(0, 1))

imgft_1 = fftpack.fft2(imagen3, axes=(0, 1))

imgft_2 = kernel1[:,:] * imgft_1

img2 = fftpack.ifft2(imgft_2, axes=(0, 1)).real

figura = figure(1, figsize=(9.5,9))
imshow(img2, cmap = cm.Greys_r)
# Out:
# (576, 544)

# %%
print ("El pasa-altas permite multiplicar una gaussiana negativa a los arrays de la foto, de tal manera que los máximos de las fotos se anulan con la gaussiana y las frecuencias bajas se multiplican por los extremos de la gaussiana que tienden a 1, de tal forma que quedan igual ")
# Out:
# El pasa-altas permite multiplicar una gaussiana negativa a los arrays de la foto, de tal manera que los máximos de las fotos se anulan con la gaussiana y las frecuencias bajas se multiplican por los extremos de la gaussiana que tienden a 1, de tal forma que quedan igual

# %%
print ("El pasa-bajas permite multiplicar una gaussiana como se mencionó anteriormente, pero esta vez positiva, haciendo coincidir las máximas frecuencias con el máximo de la gaussiana, anulando así las frecuencias bajas")
# Out:
# El pasa-bajas permite multiplicar una gaussiana como se mencionó anteriormente, pero esta vez positiva, haciendo coincidir las máximas frecuencias con el máximo de la gaussiana, anulando así las frecuencias bajas
